# %% [markdown]
# # importing the libaraies

# %%
import pandas as pd 
import numpy as np         
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('menu.csv')

# %%
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
cal=df['Calories']+df['Calories from Fat']

# %%
np.mean(cal)
# Out:
# 495.36538461538464

# %%
sns.kdeplot(data=df,x='Calories',hue='Category')    #seems like a outlier in chicken
# Out:
# <Axes: xlabel='Calories', ylabel='Density'>

# %%
df[df['Category']=='Chicken & Fish'].sort_values(by=['Calories'],ascending=False)
# Out:
#           Category                                               Item  \
# 82  Chicken & Fish                       Chicken McNuggets (40 piece)
# 81  Chicken & Fish                       Chicken McNuggets (20 piece)
# 63  Chicken & Fish            Bacon Clubhouse Crispy Chicken Sandwich
# 59  Chicken & Fish               Premium Crispy Chicken Club Sandwich
# 74  Chicken & Fish  Premium McWrap Southwest Chicken (Crispy Chicken)
# 70  Chicken & Fish    Premium McWrap Chicken & Bacon (Crispy Chicken)
# 72  Chicken & Fish    Premium McWrap Chicken & Ranch (Crispy Chicken)
# 61  Chicken & Fish          Premium Crispy Chicken Ranch BLT Sandwich
# 64  Chicken & Fish           Bacon Clubhouse Grilled Chicken Sandwich
# 76  Chicken & Fish  Premium McWrap Chicken Sweet Chili (Crispy Chi...
# 75  Chicken & Fish  Premium McWrap Southwest Chicken (Grilled Chic...
# 57  Chicken & Fish            Premium Crispy Chicken Classic Sandwich
# ...

# %%
sns.histplot(data=df,x='Category')
sns.set(rc={'figure.figsize':(20,4)})
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Breakfast'),
#   Text(1, 0, 'Beef & Pork'),
#   Text(2, 0, 'Chicken & Fish'),
#   Text(3, 0, 'Salads'),
#   Text(4, 0, 'Snacks & Sides'),
#   Text(5, 0, 'Desserts'),
#   Text(6, 0, 'Beverages'),
#   Text(7, 0, 'Coffee & Tea'),
#   Text(8, 0, 'Smoothies & Shakes')])

# %% [markdown]
#  looks like coffee and tea is popular

# %% [markdown]
#  lets see if thier is a corr between calaroies and calories from fat

# %%
sns.scatterplot(data=df,x='Calories',y='Calories from Fat')
plt.show()
correlation=df['Calories'].corr(df['Calories from Fat'])
print('correlation',correlation)
# Out:
# correlation 0.9045878034080992

# %% [markdown]
# - yes thier is as strong corr between calories and calories form fat

# %%
df.groupby('Category')['Trans Fat'].mean()
# Out:
# Category
# Beef & Pork           1.100000
# Beverages             0.000000
# Breakfast             0.107143
# Chicken & Fish        0.129630
# Coffee & Tea          0.142105
# Desserts              0.000000
# Salads                0.000000
# Smoothies & Shakes    0.535714
# Snacks & Sides        0.000000
# Name: Trans Fat, dtype: float64

# %% [markdown]
# - beef and pork have the higest trans fat

# %%
df['saturated_chol']=df['Saturated Fat']/df['Cholesterol']*100

# %%
saturated_chol=df.groupby('Category')['saturated_chol'].mean().dropna().nlargest(5)
saturated_chol
# Out:
# Category
# Coffee & Tea          14.930699
# Smoothies & Shakes    14.632262
# Beef & Pork           11.853571
# Salads                 9.974790
# Chicken & Fish         8.357976
# Name: saturated_chol, dtype: float64

# %% [markdown]
# - coffee and tea have the highest saturated  fat

# %%
plt.figure(figsize=(10, 4))
saturated_chol.sort_values(ascending=False).plot.bar()

plt.show();

# %%
coffe_tea=df[df["Category"]=='Coffee & Tea']

# %%
coffe_tea.groupby('Item')['saturated_chol'].mean().sort_values(ascending=False)
# Out:
# Item
# Frappé Chocolate Chip (Small)     21.538462
# Frappé Chocolate Chip (Medium)    21.250000
# Frappé Chocolate Chip (Large)     21.052632
# Hazelnut Iced Coffee (Small)      20.000000
# Hazelnut Latte (Medium)           20.000000
#                                     ...
# Iced Tea (Small)                        NaN
# Sweet Tea (Child)                       NaN
# Sweet Tea (Large)                       NaN
# Sweet Tea (Medium)                      NaN
# Sweet Tea (Small)                       NaN
# Name: saturated_chol, Length: 95, dtype: float64

# %% [markdown]
# -Frappé Chocolate Chip (Small) is higehst with 21.538462 saturated cholestrol

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)', 'saturated_chol'],
#       dtype='object')

# %%
beef=df[df['Category']=='Beef & Pork']
beef.groupby('Item')['saturated_chol'].mean().sort_values(ascending=False)
# Out:
# Item
# McRib                                        14.285714
# Bacon Clubhouse Burger                       13.043478
# Quarter Pounder Deluxe                       12.941176
# Quarter Pounder with Cheese                  12.631579
# Quarter Pounder with Bacon & Cheese          12.380952
# Quarter Pounder with Bacon Habanero Ranch    12.380952
# Double Quarter Pounder with Cheese           11.875000
# Big Mac                                      11.764706
# Daily Double                                 11.250000
# Jalapeño Double                              11.250000
# Bacon McDouble                               11.111111
# Cheeseburger                                 11.111111
# Double Cheeseburger                          11.111111
# McDouble                                     10.666667
# Hamburger                                    10.000000
# Name: saturated_chol, dtype: float64

# %%
smoothies=df[df['Category']=='Smoothies & Shakes']
smoothies.groupby('Item')['saturated_chol'].mean().sort_values(ascending=False)
# Out:
# Item
# McFlurry with M&M’s Candies (Snack)                  28.571429
# McFlurry with M&M’s Candies (Small)                  28.000000
# McFlurry with Reese's Peanut Butter Cups (Snack)     26.666667
# McFlurry with M&M’s Candies (Medium)                 26.666667
# McFlurry with Reese's Peanut Butter Cups (Medium)    25.000000
# McFlurry with Oreo Cookies (Medium)                  21.818182
# McFlurry with Oreo Cookies (Snack)                   20.000000
# McFlurry with Oreo Cookies (Small)                   20.000000
# Chocolate Shake (Large)                              17.647059
# Strawberry Shake (Medium)                            17.333333
# Vanilla Shake (Large)                                16.666667
# Strawberry Shake (Small)                             16.666667
# Strawberry Shake (Large)                             16.666667
# Shamrock Shake (Large)                               16.666667
# Vanilla Shake (Small)                                16.666667
# ...

# %%
chicken=df[df['Category']=='Chicken & Fish']
chicken.groupby('Item')['saturated_chol'].mean().sort_values(ascending=False)
# Out:
# Item
# Premium McWrap Southwest Chicken (Crispy Chicken)       13.333333
# Premium McWrap Chicken & Ranch (Crispy Chicken)         12.307692
# Premium McWrap Chicken & Bacon (Crispy Chicken)         11.250000
# Bacon Clubhouse Crispy Chicken Sandwich                 11.111111
# Bacon Cheddar McChicken                                 10.769231
# Premium Crispy Chicken Club Sandwich                    10.588235
# Filet-O-Fish                                            10.000000
# Bacon Buffalo Ranch McChicken                           10.000000
# Premium McWrap Chicken Sweet Chili (Crispy Chicken)      9.000000
# McChicken                                                8.571429
# Premium Crispy Chicken Ranch BLT Sandwich                8.571429
# Buffalo Ranch McChicken                                  8.571429
# Chicken McNuggets (4 piece)                              8.000000
# Premium Crispy Chicken Classic Sandwich                  7.777778
# ...

# %%
salad=df[df['Category']=='Salads']
salad.groupby('Item')['saturated_chol'].mean().sort_values(ascending=False)
# Out:
# Item
# Premium Southwest Salad (without Chicken)         20.000000
# Premium Bacon Ranch Salad (without Chicken)       14.000000
# Premium Southwest Salad with Crispy Chicken        9.000000
# Premium Bacon Ranch Salad with Crispy Chicken      8.571429
# Premium Bacon Ranch Salad with Grilled Chicken     4.705882
# Premium Southwest Salad with Grilled Chicken       3.571429
# Name: saturated_chol, dtype: float64

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)', 'saturated_chol'],
#       dtype='object')

# %%
df.groupby('Category')['Carbohydrates (% Daily Value)'].mean()
# Out:
# Category
# Beef & Pork           13.466667
# Beverages              9.592593
# Breakfast             16.571429
# Chicken & Fish        16.333333
# Coffee & Tea          14.863158
# Desserts              11.571429
# Salads                 7.166667
# Smoothies & Shakes    30.142857
# Snacks & Sides         9.615385
# Name: Carbohydrates (% Daily Value), dtype: float64

# %%
sns.scatterplot(data=df,x='Total Fat (% Daily Value)',y='Carbohydrates (% Daily Value)')
correlation_new=df['Total Fat (% Daily Value)'].corr(df['Carbohydrates (% Daily Value)'])
print('correlation between total fat and carbohydrates is',correlation_new)
# Out:
# correlation between total fat and carbohydrates is 0.4602984112391491

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)', 'saturated_chol'],
#       dtype='object')

# %%
df.groupby('Category')['Vitamin A (% Daily Value)'].mean().sort_values(ascending=False)
# Out:
# Category
# Salads                146.666667
# Chicken & Fish         20.444444
# Smoothies & Shakes     18.750000
# Coffee & Tea           10.736842
# Beef & Pork             6.933333
# Breakfast               6.928571
# Desserts                5.142857
# Snacks & Sides          4.846154
# Beverages               0.740741
# Name: Vitamin A (% Daily Value), dtype: float64

# %%
df.groupby('Category')[['Vitamin C (% Daily Value)','Vitamin A (% Daily Value)','Iron (% Daily Value)','Calcium (% Daily Value)']].mean().sort_values(by=['Vitamin C (% Daily Value)','Vitamin A (% Daily Value)','Iron (% Daily Value)','Calcium (% Daily Value)'],ascending=False)
# Out:
#                     Vitamin C (% Daily Value)  Vitamin A (% Daily Value)  \
# Category
# Salads                              28.333333                 146.666667
# Snacks & Sides                      28.153846                   4.846154
# Beverages                           23.481481                   0.740741
# Chicken & Fish                      12.629630                  20.444444
# Breakfast                            8.904762                   6.928571
# Beef & Pork                          7.333333                   6.933333
# Smoothies & Shakes                   6.964286                  18.750000
# Desserts                             4.142857                   5.142857
# Coffee & Tea                         0.000000                  10.736842
#
#                     Iron (% Daily Value)  Calcium (% Daily Value)
# Category
# Salads                         10.333333                15.000000
# Snacks & Sides                  6.615385                 6.000000
# ...

# %%
beverage=df[df['Category']=='Beverages']

# %%
beverage.groupby('Item')[['Vitamin A (% Daily Value)','Vitamin C (% Daily Value)','Iron (% Daily Value)','Calcium (% Daily Value)']].mean().sort_values(by=['Vitamin A (% Daily Value)','Vitamin C (% Daily Value)','Iron (% Daily Value)','Calcium (% Daily Value)'],ascending=False).head(10)
# Out:
#                                    Vitamin A (% Daily Value)  \
# Item
# 1% Low Fat Milk Jug                                     10.0
# Fat Free Chocolate Milk Jug                             10.0
# Minute Maid Orange Juice (Large)                         0.0
# Minute Maid Orange Juice (Medium)                        0.0
# Minute Maid Orange Juice (Small)                         0.0
# Minute Maid 100% Apple Juice Box                         0.0
# Coca-Cola Classic (Child)                                0.0
# Coca-Cola Classic (Large)                                0.0
# Coca-Cola Classic (Medium)                               0.0
# Coca-Cola Classic (Small)                                0.0
#
#                                    Vitamin C (% Daily Value)  \
# Item
# 1% Low Fat Milk Jug                                      4.0
# Fat Free Chocolate Milk Jug                              0.0
# Minute Maid Orange Juice (Large)                       240.0
# ...

# %%
iron=df.groupby('Category')['Iron (% Daily Value)'].mean()
calcium=df.groupby('Category')['Calcium (% Daily Value)'].mean()

# %%
category = iron.index #putting the index name in category
Iron = iron.values  #putting the values of iron in Iron
Calcium = calcium.values

# %%
plt.figure(figsize=(10, 4), dpi=100)


X_axis = np.arange(len(category))

plt.bar(X_axis -0.2, Iron,0.4, label = 'Iron', color = 'red')
plt.bar(X_axis + 0.2, Calcium, 0.4, label = 'Calcium', color = 'yellow')

plt.xticks(X_axis, category)
plt.xlabel("Menu ")
plt.title("Distribution of Iron and Calcium in McDonald's Foods")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# # Summary

# %% [markdown]
# - Coffee and tea have the highest saturated fat to cholesterol ratio among all categories.

# %% [markdown]
# - Salads have the highest vitamin A and vitamin C content among all categories.

# %% [markdown]
# - Beef and pork have the highest iron content among all categories.

# %% [markdown]
# - Smoothies and shakes have the highest calcium content among all categories.

# %% [markdown]
# * The analysis reveals some insights into the nutritional value and health implications of different categories and items.
# * The analysis also suggests some possible areas for improvement or further investigation, such as reducing the trans fat and sodium content, increasing the dietary fiber and protein content, and diversifying the vitamin and mineral sources.
